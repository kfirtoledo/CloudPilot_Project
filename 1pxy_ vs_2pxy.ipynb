# %% [markdown]
# # One Proxy vs Two Proxies

# %% [markdown]
# ## same cloud

# %%
# %matplotlib inline
from Graphs.aux_func.plot_func_aux import host_target_proxy_box_plot_bw_rtt
from Graphs.aux_func.data_func_aux import PROJECT_PATH
from matplotlib import pyplot as plt

RESULT_PATH=PROJECT_PATH+"/results/"

# %%
host_target_proxy_box_plot_bw_rtt(RESULT_PATH+ "latest/large_window/host-us-east1-b_gcp/target-us-west1-a_gcp/proxy-us-central1-a_gcp",\
                                  fig_idx=0,type_arr=["bw"],title_prefix=" (using 1 proxy)")
host_target_proxy_box_plot_bw_rtt(RESULT_PATH+ "latest/large_window/2proxy/host-us-east1-c_gcp/target-us-west1-a_gcp/proxy-us-east1-b_gcp",\
                                   fig_idx=1,type_arr=["bw"],title_prefix=" (using 2 proxies)")
