# %% [markdown]
# # Result for K-proxies placement

# %% [markdown]
# ## Same Cloud

# %%
from IPython import display
display.Image("./Graphs/output/Graphs/all_graph/final_graph/Throughput_vs_RTT_(same_cloud)_0.png")

# %%
display.Image("./Graphs/output/Graphs/all_graph/final_graph/Throughput_vs_RTT_(same_cloud)_Ratio_0.png")

# %% [markdown]
# ## All Experiments

# %%
display.Image("./Graphs/output/Graphs/all_graph/final_graph/Throughput_vs_RTT_all_0.png")

# %%
display.Image("./Graphs/output/Graphs/all_graph/final_graph//Throughput_vs_RTT_all-_Ratio_0.png")
